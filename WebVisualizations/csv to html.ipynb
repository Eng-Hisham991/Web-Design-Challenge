# %%
import pandas as pd

# %%
path= "Resources/cities.csv"

# %%
a=pd.read_csv(path, encoding="utf-8", index_col=["City_ID", "City", "Cloudiness", "Country", "Date", "Humidity", "Lat","Lng","Max Temp","Wind Speed"])
a.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(0, jacareacanga, 0, BR, 1528902000, 62, -6.22, -57.76, 89.6, 6.93), (1, kaitangata, 100, NZ, 1528905304, 94, -46.28, 169.85, 42.61, 5.64), (2, goulburn, 20, AU, 1528905078, 91, -34.75, 149.72, 44.32, 10.11), (3, lata, 76, IN, 1528905305, 89, 30.78, 78.62, 59.89, 0.94), (4, chokurdakh, 0, RU, 1528905306, 88, 70.62, 147.9, 32.17, 2.95)]

# %%
a.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(0, jacareacanga, 0, BR, 1528902000, 62, -6.22, -57.76, 89.6, 6.93), (1, kaitangata, 100, NZ, 1528905304, 94, -46.28, 169.85, 42.61, 5.64), (2, goulburn, 20, AU, 1528905078, 91, -34.75, 149.72, 44.32, 10.11), (3, lata, 76, IN, 1528905305, 89, 30.78, 78.62, 59.89, 0.94), (4, chokurdakh, 0, RU, 1528905306, 88, 70.62, 147.9, 32.17, 2.95)]

# %%
b= a.to_html()

# %%
print(a.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>jacareacanga</th>
#       <th>0</th>
#       <th>BR</th>
#       <th>1528902000</th>
#       <th>62</th>
#       <th>-6.22</th>
#       <th>-57.76</th>
#       <th>89.60</th>
#       <th>6.93</th>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>kaitangata</th>
#       <th>100</th>
#       <th>NZ</th>
#       <th>1528905304</th>
#       <th>94</th>
#       <th>-46.28</th>
# ...
